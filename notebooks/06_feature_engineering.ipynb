# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd
import sys
import os
import warnings

warnings.filterwarnings("ignore")

# On connecte le notebook à tous les fichiers inclus dans le dossier /fonctions
sys.path.insert(0, os.path.abspath("../fonctions"))

# %load_ext autoreload
# %autoreload 

from feature_engineering import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Chargement de la base de données

df = pd.read_csv("../data_finale/train.csv")

# %%
# On génère de nouvelles features

df = generer_feature_engineering_football(df)
# Out:
# Début de la création des nouvelles variables (Feature Engineering)...
# Colonnes de postes détectées pour la polyvalence : ['pos_DF', 'pos_FW', 'pos_GK', 'pos_MF']
#
# Feature Engineering terminé ! Nombre total de colonnes : 166

# %%
df
# Out:
#                player             team nation  age  Playing Time_MP  \
# 0      Aaron Connolly         Brighton    IRL   20               17
# 1      Aaron Connolly         Brighton    IRL   21                4
# 2     Aaron Cresswell  West Ham United    ENG   31               36
# 3     Aaron Cresswell  West Ham United    ENG   32               31
# 4     Aaron Cresswell  West Ham United    ENG   33               28
# ...               ...              ...    ...  ...              ...
# 8100    Šime Vrsaljko  Atlético Madrid    CRO   28                9
# 8101    Šime Vrsaljko  Atlético Madrid    CRO   29               21
# 8102      Ștefan Radu            Lazio    ROU   34               31
# 8103      Ștefan Radu            Lazio    ROU   35               10
# 8104      Ștefan Radu            Lazio    ROU   36                1
#
#       Playing Time_Starts  Playing Time_90s  Performance_Gls  Performance_Ast  \
# 0                       9               8.8                2                1
# 1                       1               1.7                0                0
# 2                      36              35.2                0                8
# 3                      31              30.3                2                3
# 4                      24              24.8                0                1
# ...                   ...               ...              ...              ...
# 8100                    6               5.8                0                0
# 8101                   10              10.2                1                2
# 8102                   30              27.3                0                3
# 8103                    6               6.2                0                0
# 8104                    0               0.0                0                0
#
#       Performance_G-PK  ...  taux_indisponibilite  taux_indisponibilite_prec  \
# 0                    2  ...              0.205479                   0.000000
# 1                    0  ...              0.000000                   0.205479
# 2                    0  ...              0.030137                   0.000000
# 3                    2  ...              0.000000                   0.030137
# 4                    0  ...              0.000000                   0.000000
# ...                ...  ...                   ...                        ...
# 8100                 0  ...              0.000000                   0.000000
# 8101                 1  ...              0.594521                   0.000000
# 8102                 0  ...              0.172603                   0.000000
# 8103                 0  ...              0.131507                   0.172603
# 8104                 0  ...              0.084932                   0.131507
#
#       fragilite_chronique  score_hype_nation  urgence_contractuelle  \
# 0                       0                  0                      0
# 1                       0                  0                      0
# 2                       0                  7                      0
# 3                       0                  6                      0
# 4                       0                  7                      0
# ...                   ...                ...                    ...
# 8100                    0                  0                      0
# 8101                    0                  0                      0
# 8102                    0                  0                      0
# 8103                    0                  0                      0
# 8104                    0                  0                      0
#
#       impact_buts_points  indiscipline_par_90  ratio_buts_hors_penalty  \
# 0               0.103529             0.000000                      1.0
# 1               0.000000             0.000000                      0.0
# 2               0.000000             0.085227                      0.0
# 3               0.093548             0.099010                      1.0
# 4               0.000000             0.120968                      0.0
# ...                  ...                  ...                      ...
# 8100            0.000000             0.344828                      0.0
# 8101            0.088571             0.392157                      1.0
# 8102            0.000000             0.073260                      0.0
# 8103            0.000000             0.322581                      0.0
# 8104            0.000000             0.000000                      0.0
#
#       est_polyvalent  taux_matchs_termines
# 0                  1              0.111111
# 1                  0              0.000000
# 2                  0              0.944444
# 3                  0              0.935484
# 4                  0              0.833333
# ...              ...                   ...
# 8100               0              0.500000
# 8101               1              0.400000
# 8102               0              0.633333
# 8103               0              0.500000
# 8104               0              0.000000
#
# [8105 rows x 166 columns]
