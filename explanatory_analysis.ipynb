# %%
# %pip install app
# %pip install app.utils
# %pip install app.services
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement app.services (from versions: none)
# ERROR: No matching distribution found for app.services

# %%
import os

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 4
#       1 import json
#       2 from dataclasses import dataclass
#       3
# ----> 4 from app.services.base import TransfermarktBase
#       5 from app.utils.regex import REGEX_CHART_CLUB_ID
#       6 from app.utils.utils import safe_regex, zip_lists_into_dict
#       7 from app.utils.xpath import Players
#
# ModuleNotFoundError: No module named 'app.services'

# %%
import os
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tmapi (from versions: none)
# ERROR: No matching distribution found for tmapi

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from tmapi import Transfermarkt
#       2
#       3 tm = Transfermarkt()
#       4
#
# ModuleNotFoundError: No module named 'tmapi'
